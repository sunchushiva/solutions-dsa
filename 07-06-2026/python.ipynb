# %%
import math

n = 5
symbol = "&"


def extra_spacing(current, end, pattern, output):

    if current != end:
        output += pattern + "!"
    else:
        output += pattern

    return output

# %%
def incremental_numerical_inverted_pattern(n=4):

    normal = (n * 2) + 1
    middle = n**2 + 1
    outlier = 1

    for a in range(1, n + 2):

        output = ""
        for b in range(1, n + 1):

            if a == math.ceil((n + (1 if n % 2 == 0 else 2)) / 2):
                output = extra_spacing(b, n, f"{middle}", output)
                middle += 1
            elif a != n + 1 and a != 1:
                output = extra_spacing(b, n, f"{normal}", output)
                normal += 1
            else:
                output = extra_spacing(b, n, f"{outlier}", output)
                outlier += 1

        print(output)

    return None


incremental_numerical_inverted_pattern()
# Out:
# 1!2!3!4
# 9!10!11!12
# 17!18!19!20
# 13!14!15!16
# 5!6!7!8

# %%
def incremental_numerical_inverse_pattern(n=4):

    even_calc = math.ceil(n / 2) + 1
    odd_calc = 1
    even = even_calc * n
    odd = odd_calc * n

    for a in range(1, n + 1):

        output = ""
        for b in range(1, n + 1):

            if a % 2 == 0:
                output = extra_spacing(b, n, f"{even}", output)
                even -= 1
            else:
                output = extra_spacing(b, n, f"{odd}", output)
                odd -= 1

        print(output)

        if a % 2 == 0:
            even_calc += 1
            even = even_calc * n
        else:
            odd_calc += 1
            odd = odd_calc * n

    return None


incremental_numerical_inverse_pattern(n)
# Out:
# 5!4!3!2!1
# 20!19!18!17!16
# 10!9!8!7!6
# 25!24!23!22!21
# 15!14!13!12!11

# %%
# incomlete function
def basic_incremental_inverted_pattern(n=4):

    odd = 1
    even = 4

    for a in range(1, n + 1):

        ref = 1

    return None


basic_incremental_inverted_pattern()
